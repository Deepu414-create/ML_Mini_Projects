# %%
""""Project Name: Simple_Linear_Regression_Prediction

Description:This project demonstrates a basic implementation of Linear Regression using Python. It trains a simple model on a small dataset, makes predictions, and visualizes the results. The project uses NumPy for data handling, Pandas for data manipulation, Matplotlib for plotting, and Scikit-learn for building the machine learning model.

Key Features:
1.Train a linear regression model on sample data
2.Predict new values based on the trained model
3.Visualize data points and the regression line
4.Understand the basics of supervised machine learning

Technologies Used:

1.Python
2.NumPy
3.Pandas
4.Matplotlib
5.Scikit-learn

Usage:

1.Clone the repository
2.Install required libraries (numpy, pandas, matplotlib, scikit-learn)
3.Run day1_test.py to see predictions and plot the regression line
"""



import sys
print(sys.executable)
print(sys.version)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

print("✅ All libraries are working!")

# quick ML test
X = np.array([[1], [2], [3], [4], [5]])
y = np.array([2, 4, 6, 8, 10])

model = LinearRegression()
model.fit(X, y)

print("Prediction for 6:", model.predict([[6]])[0])
# day1_test.py

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Step 1: Create sample data
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)  # Features
y = np.array([2, 4, 6, 8, 10])  # Labels

# Step 2: Train simple model
model = LinearRegression()
model.fit(X, y)

# Step 3: Make prediction
prediction = model.predict([[6]])
print("Prediction for input 6:", prediction[0])

# Step 4: Visualize
plt.scatter(X, y, color="blue", label="Data")
plt.plot(X, model.predict(X), color="red", label="Model")
plt.legend()
plt.show()
# Out:
# c:\Program Files\Python312\python.exe
# 3.12.0 (tags/v3.12.0:0fb18b0, Oct  2 2023, 13:03:39) [MSC v.1935 64 bit (AMD64)]
# ✅ All libraries are working!
# Prediction for 6: 12.0
# Prediction for input 6: 12.0
